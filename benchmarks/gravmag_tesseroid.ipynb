# %% [markdown]
# # Benchmark the performance of gravmag.tesseroid
#
# Compare the fatiando implementation with [Tesseroids](http://leouieda.github.com/tesseroids/)

# %%
# %pylab inline
import re
import numpy
from fatiando import gridder, gravmag
from fatiando.mesher import Tesseroid, TesseroidMesh
from fatiando.vis import mpl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Setup
#
# Make a model with a lot of tesseroids.
# Doesn't really matter that they are overlapping as I'm only interested in the speed.

# %%
# The setup
model = TesseroidMesh((70, 110, -20, 20, 0, -50000), (1, 20, 20))
model.addprop('density', 2700*numpy.ones(model.size))
area = [80, 100, -10, 10]
shape = [50, 50]
lon, lat, height = gridder.regular(area, shape, z=150000)

# Create a model file and a grid file for Tesseroids
modfile = 'model.tmp'
with open(modfile, 'w') as f:
    for t in model:
        f.write('%g %g %g %g %g %g %g\n'
            % (t.w, t.e, t.s, t.n, t.top, t.bottom, t.props['density']))
gridfile = 'grid.tmp'
numpy.savetxt(gridfile, numpy.transpose([lon, lat, height]), fmt='%g')

lines = !wc -l model.tmp
print "lines", lines[0]
# !head model.tmp
lines = !wc -l grid.tmp
print "lines", lines[0]
# !head grid.tmp
# Out:
# lines 400 model.tmp
# 70 72 -20 -18 0 -50000 2700
# 72 74 -20 -18 0 -50000 2700
# 74 76 -20 -18 0 -50000 2700
# 76 78 -20 -18 0 -50000 2700
# 78 80 -20 -18 0 -50000 2700
# 80 82 -20 -18 0 -50000 2700
# 82 84 -20 -18 0 -50000 2700
# 84 86 -20 -18 0 -50000 2700
# 86 88 -20 -18 0 -50000 2700
# 88 90 -20 -18 0 -50000 2700
# lines 2500 grid.tmp
# 80 -10 150000
# 80.4082 -10 150000
# 80.8163 -10 150000
# 81.2245 -10 150000
# 81.6327 -10 150000
# 82.0408 -10 150000
# 82.449 -10 150000
# 82.8571 -10 150000
# 83.2653 -10 150000
# 83.6735 -10 150000

# %% [markdown]
# ## Time the execution
#
# First, run Tesseroids on the model:

# %%
# Time Tesseroids
print "Tesseroids:"
def timetess():
    # !/home/leo/src/tesseroids/bin/tessgzz model.tmp < grid.tmp > out.tmp
# %timeit timetess()
# Out:
# Tesseroids:
# 1 loops, best of 3: 3.8 s per loop

# %% [markdown]
# Now run the fatiando implementation:

# %%
# Time fatiando.gravmag.tesseroid
print "fatiando.gravmag.tesseroid:"
# %timeit gravmag.tesseroid.gzz(lon, lat, height, model)
# Out:
# fatiando.gravmag.tesseroid:
# 1 loops, best of 3: 3.64 s per loop

# %%
result = gravmag.tesseroid.gzz(lon, lat, height, model)

# %% [markdown]
# Do some checks on the results

# %%
# Check the results
result_tesseroids = numpy.loadtxt('out.tmp', usecols=(-1,), unpack=True)
diff = result_tesseroids - result

# %%
print abs(diff).max(), abs(result_tesseroids).max(), abs(result).max(), abs(result_tesseroids).min(), abs(result).min()
# Out:
# 3.67500393565e-05 46.7479556967 46.7479556965 39.1759403884 39.1759400253

# %%
mpl.figure(figsize=(21, 5))
mpl.subplot(1, 3, 1)
mpl.axis('scaled')
mpl.contourf(lon, lat, result_tesseroids, shape, 30)
mpl.colorbar()
mpl.subplot(1, 3, 2)
mpl.axis('scaled')
mpl.contourf(lon, lat, result, shape, 30)
mpl.colorbar()
mpl.subplot(1, 3, 3)
mpl.axis('scaled')
mpl.contourf(lon, lat, diff, shape, 30)
mpl.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x491a0e0>

# %% [markdown]
# ## Profile the code

# %% [markdown]
# First run cProfile to get a feel for the function calls.

# %%
# %prun -T gravmag_tesseroid.profile gravmag.tesseroid.gzz(lon, lat, height, model)
# Out:
#
# *** Profile printout saved to text file u'gravmag_tesseroid.profile'.

# %%
# !cat gravmag_tesseroid.profile
# Out:
#          1251542 function calls in 4.108 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     41168    2.064    0.000    2.137    0.000 _ctesseroid.pyx:440(gzz)
#         1    0.943    0.943    4.108    4.108 tesseroid.py:99(_optimal_discretize)
#     41168    0.227    0.000    0.227    0.000 _ctesseroid.pyx:41(distance)
#     41168    0.203    0.000    0.203    0.000 _ctesseroid.pyx:22(too_close)
#     41168    0.101    0.000    2.412    0.000 {fatiando.gravmag._ctesseroid.gzz}
#    164672    0.099    0.000    0.099    0.000 stringsource:323(__cinit__)
#     41168    0.096    0.000    0.131    0.000 mesher.py:455(__init__)
#      5096    0.065    0.000    0.194    0.000 mesher.py:489(half)
#    164672    0.064    0.000    0.162    0.000 stringsource:618(memoryview_cwrapper)
#     41168    0.055    0.000    0.055    0.000 _ctesseroid.pyx:63(_scale_nodes)
#     41168    0.035    0.000    0.035    0.000 mesher.py:46(__init__)
#     41168    0.028    0.000    0.028    0.000 {max}
#     41168    0.022    0.000    0.250    0.000 {fatiando.gravmag._ctesseroid.distance}
#     41168    0.019    0.000    0.222    0.000 {fatiando.gravmag._ctesseroid.too_close}
#     41168    0.018    0.000    0.018    0.000 {method 'pop' of 'list' objects}
#    164672    0.017    0.000    0.017    0.000 stringsource:345(__dealloc__)
#      5096    0.014    0.000    0.023    0.000 {method 'extend' of 'list' objects}
#    164672    0.012    0.000    0.012    0.000 stringsource:624(memoryview_check)
#     45864    0.009    0.000    0.009    0.000 tesseroid.py:143(<genexpr>)
#     82337    0.009    0.000    0.009    0.000 {len}
#       400    0.005    0.000    0.007    0.000 mesher.py:1078(__getitem__)
#       401    0.001    0.000    0.008    0.000 mesher.py:1103(next)
#       800    0.001    0.000    0.001    0.000 mesher.py:1096(<genexpr>)
#         6    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#         1    0.000    0.000    4.108    4.108 tesseroid.py:90(gzz)
#         1    0.000    0.000    0.000    0.000 {numpy.core.multiarray.arange}
#         1    0.000    0.000    4.108    4.108 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 mesher.py:1099(__iter__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# Run [line_profiler](http://pythonhosted.org/line_profiler/) on _optimal_discretize to see what is slowing it down.

# %%
from line_profiler import LineProfiler

# %%
lp = LineProfiler(gravmag.tesseroid._optimal_discretize)
lp.runcall(gravmag.tesseroid.gzz, lon, lat, height, model)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# File: /home/leo/src/fatiando/fatiando/gravmag/tesseroid.py
# Function: _optimal_discretize at line 99
# Total time: 5.04368 s
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     99                                           def _optimal_discretize(tesseroids, lons, lats, heights, kernel, ratio, dens):
#    100                                               """
#    101                                               Calculate the effect of a given kernal in the most precise way by adaptively
#    102                                               discretizing the tesseroids into smaller ones.
#    103                                               """
#    104         1            4      4.0      0.0      ndata = len(lons)
#    105                                               # Convert things to radians
#    106         1           17     17.0      0.0      d2r = numpy.pi/180.
#    107         1           51     51.0      0.0      rlons = d2r*lons
#    108         1           53     53.0      0.0      sinlats = numpy.sin(d2r*lats)
#    109         1           73     73.0      0.0      coslats = numpy.cos(d2r*lats)
#    110                                               # Transform the heights into radii
#    111         1           14     14.0      0.0      radii = MEAN_EARTH_RADIUS + heights
#    112                                               # Create some buffers to reduce memory allocation
#    113         1           16     16.0      0.0      buff = numpy.zeros(ndata, numpy.float)
#    114         1            4      4.0      0.0      lonc = numpy.zeros(2, numpy.float)
#    115         1            3      3.0      0.0      sinlatc = numpy.zeros(2, numpy.float)
#    116         1            3      3.0      0.0      coslatc = numpy.zeros(2, numpy.float)
#    117         1            3      3.0      0.0      rc = numpy.zeros(2, numpy.float)
#    118         1           16     16.0      0.0      allpoints = numpy.arange(ndata)
#    119                                               # Start the computations
#    120         1           10     10.0      0.0      result = numpy.zeros(ndata, numpy.float)
#    121       401        15101     37.7      0.3      for tesseroid in tesseroids:
#    122       400          609      1.5      0.0          if (tesseroid is None or
#    123       400          572      1.4      0.0              ('density' not in tesseroid.props and dens is None)):
#    124                                                       continue
#    125       400          523      1.3      0.0          if dens is not None:
#    126                                                       density = dens
#    127                                                   else:
#    128       400          571      1.4      0.0              density = tesseroid.props['density']
#    129       400          647      1.6      0.0          lifo = [[allpoints, tesseroid]]
#    130     41568        71821      1.7      1.4          while lifo:
#    131     41168       108392      2.6      2.1              points, tess = lifo.pop()
#    132     41168        77485      1.9      1.5              size = max([MEAN_EARTH_RADIUS*d2r*(tess.e - tess.w),
#    133     41168        64767      1.6      1.3                          MEAN_EARTH_RADIUS*d2r*(tess.n - tess.s),
#    134     41168       104666      2.5      2.1                          tess.top - tess.bottom])
#    135     41168        61998      1.5      1.2              distances = _kernels.distance(tess, rlons, sinlats, coslats,
#    136     41168       335194      8.1      6.6                      radii, points, buff)
#    137                                                       #too_close = (distances > 0) & (distances < ratio*size)
#    138                                                       #need_divide = points[too_close]
#    139                                                       #dont_divide = points[~too_close]
#    140     41168        63125      1.5      1.3              need_divide, dont_divide = _kernels.too_close(points, distances,
#    141     41168       325288      7.9      6.4                      ratio*size)
#    142     41168        73744      1.8      1.5              if len(need_divide):
#    143      5096       428217     84.0      8.5                  lifo.extend([need_divide, t] for t in tess.half())
#    144     41168        60364      1.5      1.2              if len(dont_divide):
#    145     41168       161803      3.9      3.2                  result[dont_divide] += density*kernel(
#    146     41168       150318      3.7      3.0                      tess, rlons[dont_divide], sinlats[dont_divide],
#    147     41168       141189      3.4      2.8                      coslats[dont_divide], radii[dont_divide], lonc, sinlatc,
#    148     41168      2797008     67.9     55.5                      coslatc, rc, buff)
#    149         1            9      9.0      0.0      result *= G
#    150         1            2      2.0      0.0      return result
