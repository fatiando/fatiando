# %%
# %pylab inline
from line_profiler import LineProfiler
from fatiando import gravmag, gridder, utils, mesher
from fatiando.vis import mpl
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# Make synthetic data
inc, dec = -60, 23
props = {'magnetization':10}
model = [mesher.Prism(-500, 500, -1000, 1000, 500, 4000, props)]
shape = (25, 25)
x, y, z = gridder.regular([-5000, 5000, -5000, 5000], shape, z=-150)
tf = utils.contaminate(gravmag.prism.tf(x, y, z, model, inc, dec), 5)
# Estimate the magnetization intensity
data = [gravmag.eqlayer.TotalField(x, y, z, tf, inc, dec)]
# Setup the layer
grid = mesher.PointGrid([-5000, 5000, -5000, 5000], 200, (60, 60))

# %% [markdown]
# # Test the layers
#
# Run the PEL once to see if the results are OK

# %%
intensity, matrices = gravmag.eqlayer.pel(data, grid, (15, 15), degree=1, damping=10.**-15, smoothness=10.**-1)
grid.addprop('magnetization', intensity)
predicted = gravmag.sphere.tf(x, y, z, grid, inc, dec)
residuals = tf - predicted
print "Residuals:"
print "mean:", residuals.mean()
print "stddev:", residuals.std()
# Out:
# Residuals:
# mean: 1.88194960514
# stddev: 5.9619625961

# %%
# Plot the layer and the fit
mpl.figure(figsize=(14,3))
mpl.subplot(1, 3, 1)
mpl.axis('scaled')
mpl.title('Layer (A/m)')
mpl.pcolor(grid.y, grid.x, grid.props['magnetization'], grid.shape)
mpl.colorbar()
mpl.m2km()
mpl.subplot(1, 3, 2)
mpl.axis('scaled')
mpl.title('Fit (nT)')
levels = mpl.contour(y, x, tf, shape, 15, color='r')
mpl.contour(y, x, predicted, shape, levels, color='k')
mpl.m2km()
mpl.subplot(1, 3, 3)
mpl.title('Residuals (nT)')
mpl.hist(residuals, bins=10)
# Out:
# (array([  1,   2,  13,  95, 378, 101,  16,  12,   6,   1]),
#  array([-27.34925229, -21.00801561, -14.66677893,  -8.32554225,
#         -1.98430557,   4.35693111,  10.69816779,  17.03940447,
#         23.38064115,  29.72187783,  36.06311451]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Run a classic layer to see

# %%
intensity, predicted = gravmag.eqlayer.classic(data, grid, damping=0.01)
grid.addprop('magnetization', intensity)
residuals = tf - predicted[0]
print "Residuals:"
print "mean:", residuals.mean()
print "stddev:", residuals.std()
# Out:
# Residuals:
# mean: 3.52208399977
# stddev: 4.24282520679

# %%
# Plot the layer and the fit
mpl.figure(figsize=(14,3))
mpl.subplot(1, 3, 1)
mpl.axis('scaled')
mpl.title('Layer (A/m)')
mpl.pcolor(grid.y, grid.x, grid.props['magnetization'], grid.shape)
mpl.colorbar()
mpl.m2km()
mpl.subplot(1, 3, 2)
mpl.axis('scaled')
mpl.title('Fit (nT)')
levels = mpl.contour(y, x, tf, shape, 15, color='r')
mpl.contour(y, x, predicted[0], shape, levels, color='k')
mpl.m2km()
mpl.subplot(1, 3, 3)
mpl.title('Residuals (nT)')
mpl.hist(residuals, bins=10)
# Out:
# (array([264, 121,  83,  71,  32,  20,  12,  10,   7,   5]),
#  array([ -0.95710493,   1.24403015,   3.44516523,   5.64630032,
#          7.8474354 ,  10.04857048,  12.24970556,  14.45084064,
#         16.65197572,  18.85311081,  21.05424589]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Benchmark them

# %%
# %timeit gravmag.eqlayer.classic(data, grid, damping=0.01)
# Out:
# 1 loops, best of 3: 1.42 s per loop

# %%
# %timeit gravmag.eqlayer.pel(data, grid, (15, 15), degree=1, damping=10.**-15, smoothness=10.**-1)
# Out:
# 1 loops, best of 3: 2.29 s per loop

# %% [markdown]
# # Profiling Classic

# %%
# %prun -T gravmag_eqlayer.classic.profile gravmag.eqlayer.classic(data, grid, damping=0.01)
# !cat gravmag_eqlayer.classic.profile
# Out:
#
# *** Profile printout saved to text file u'gravmag_eqlayer.classic.profile'.
#          72428 function calls in 1.433 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3600    0.663    0.000    0.810    0.000 sphere.py:57(tf)
#        23    0.377    0.016    0.377    0.016 {numpy.core._dotblas.dot}
#      7290    0.202    0.000    0.202    0.000 {numpy.core.multiarray.array}
#      3601    0.042    0.000    0.042    0.000 utils.py:237(dircos)
#         2    0.029    0.015    0.029    0.015 {numpy.core.multiarray.concatenate}
#      3600    0.025    0.000    0.065    0.000 linalg.py:1840(norm)
#      3600    0.019    0.000    0.034    0.000 mesher.py:683(__getitem__)
#         1    0.016    0.016    1.022    1.022 eqlayer.py:55(sensitivity)
#      3600    0.009    0.000    0.011    0.000 mesher.py:559(__init__)
#      3600    0.008    0.000    0.008    0.000 {numpy.core.multiarray.empty_like}
#      3600    0.006    0.000    0.006    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      3601    0.006    0.000    0.040    0.000 mesher.py:698(next)
#      3600    0.006    0.000    0.006    0.000 {method 'fill' of 'numpy.ndarray' objects}
#      3600    0.004    0.000    0.018    0.000 numeric.py:65(zeros_like)
#      7200    0.004    0.000    0.004    0.000 mesher.py:689(<genexpr>)
#      3600    0.003    0.000    0.003    0.000 mesher.py:49(__init__)
#      3648    0.003    0.000    0.186    0.000 numeric.py:167(asarray)
#      7251    0.003    0.000    0.003    0.000 {isinstance}
#      3601    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.002    0.002    1.433    1.433 <string>:1(<module>)
#         1    0.001    0.001    0.015    0.015 iterative.py:192(cg)
#      3600    0.001    0.000    0.001    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    1.431    1.431 eqlayer.py:63(classic)
#        40    0.000    0.000    0.013    0.000 interface.py:92(matvec)
#        41    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        42    0.000    0.000    0.000    0.000 numeric.py:237(asanyarray)
#         1    0.000    0.000    0.000    0.000 {method 'trace' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.013    0.001 interface.py:232(matvec)
#         1    0.000    0.000    0.155    0.155 fromnumeric.py:32(_wrapit)
#         1    0.000    0.000    0.000    0.000 utils.py:28(make_system)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:2116(rank)
#         1    0.000    0.000    0.000    0.000 interface.py:203(aslinearoperator)
#         1    0.000    0.000    0.000    0.000 {range}
#         1    0.000    0.000    0.155    0.155 fromnumeric.py:445(transpose)
#         2    0.000    0.000    0.000    0.000 sputils.py:96(isshape)
#         2    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#         1    0.000    0.000    0.000    0.000 shape_base.py:58(atleast_2d)
#         2    0.000    0.000    0.000    0.000 interface.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:986(trace)
#         3    0.000    0.000    0.000    0.000 {getattr}
#        20    0.000    0.000    0.000    0.000 utils.py:25(id)
#         4    0.000    0.000    0.000    0.000 sputils.py:111(issequence)
#         3    0.000    0.000    0.000    0.000 {hasattr}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:77(postprocess)
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 sputils.py:81(isintlike)
#         1    0.000    0.000    0.000    0.000 utils.py:18(coerce)
#         1    0.000    0.000    0.000    0.000 mesher.py:694(__iter__)
#         5    0.000    0.000    0.000    0.000 {len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
lp = LineProfiler(gravmag.eqlayer.classic)
lp.runcall(gravmag.eqlayer.classic, data, grid, 0.01)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# File: /home/leo/src/fatiando/fatiando/gravmag/eqlayer.py
# Function: classic at line 63
# Total time: 1.59329 s
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     63                                           def classic(data, grid, damping=0.):
#     64                                               """
#     65                                               The classic equivalent layer with damping regularization.
#     66                                               """
#     67         2      1212888 606444.0     76.1      sensitivity = numpy.concatenate([d.sensitivity(grid) for d in data])
#     68         2           23     11.5      0.0      datavec = numpy.concatenate([d.data for d in data])
#     69         1       357433 357433.0     22.4      system = numpy.dot(sensitivity, sensitivity.T)
#     70         1            7      7.0      0.0      if damping != 0.:
#     71         1            4      4.0      0.0          order = len(system)
#     72         1           97     97.0      0.0          scale = float(numpy.trace(system))/order
#     73         1           17     17.0      0.0          diag = range(order)
#     74         1          710    710.0      0.0          system[diag, diag] += damping*scale
#     75         1        16872  16872.0      1.1      tmp = linalg.cg(system, datavec)[0]
#     76         1         2482   2482.0      0.2      estimate = numpy.dot(sensitivity.T, tmp)
#     77         1         2740   2740.0      0.2      pred = numpy.dot(sensitivity, estimate)
#     78         1            2      2.0      0.0      predicted = []
#     79         1            0      0.0      0.0      start = 0
#     80         2            3      1.5      0.0      for d in data:
#     81         1            8      8.0      0.0          predicted.append(pred[start:start + d.size])
#     82         1            2      2.0      0.0          start += d.size
#     83         1            1      1.0      0.0      return estimate, predicted

# %% [markdown]
# # Profiling PEL

# %%
# %prun -T gravmag_eqlayer.pel.profile gravmag.eqlayer.pel(data, grid, (15, 15), degree=1, damping=10.**-15, smoothness=10.**-1)
# !cat gravmag_eqlayer.pel.profile
# Out:
#
# *** Profile printout saved to text file u'gravmag_eqlayer.pel.profile'.
#          222341 function calls (222339 primitive calls) in 2.465 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2575    1.090    0.000    1.090    0.000 {numpy.core._dotblas.dot}
#      3600    0.704    0.000    0.860    0.000 sphere.py:57(tf)
#     20899    0.237    0.000    0.237    0.000 {numpy.core.multiarray.array}
#         1    0.068    0.068    0.891    0.891 iterative.py:192(cg)
#      3825    0.047    0.000    0.047    0.000 utils.py:237(dircos)
#      3600    0.027    0.000    0.069    0.000 linalg.py:1840(norm)
#         1    0.021    0.021    1.547    1.547 eqlayer.py:192(_pel_matrices)
#      3600    0.020    0.000    0.037    0.000 mesher.py:683(__getitem__)
#       225    0.019    0.000    1.094    0.005 eqlayer.py:55(sensitivity)
#       678    0.015    0.000    0.029    0.000 compressed.py:101(check_format)
#      3796    0.012    0.000    0.823    0.000 interface.py:92(matvec)
#       450    0.011    0.000    0.020    0.000 eqlayer.py:104(_bkmatrix)
#     29633    0.010    0.000    0.010    0.000 {isinstance}
#      3360    0.010    0.000    0.014    0.000 lil.py:226(_insertat2)
#      3600    0.009    0.000    0.013    0.000 mesher.py:559(__init__)
#       678    0.009    0.000    0.010    0.000 compressed.py:622(prune)
#      4697    0.009    0.000    0.009    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      3600    0.008    0.000    0.008    0.000 {numpy.core.multiarray.empty_like}
#     10793    0.007    0.000    0.215    0.000 numeric.py:167(asarray)
#      3600    0.007    0.000    0.007    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      3825    0.006    0.000    0.043    0.000 mesher.py:698(next)
#      3600    0.006    0.000    0.006    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     13665    0.006    0.000    0.008    0.000 numeric.py:1574(isscalar)
#   678/676    0.006    0.000    0.048    0.000 compressed.py:20(__init__)
#       225    0.005    0.000    1.100    0.005 eqlayer.py:133(_gkmatrix)
#       452    0.005    0.000    0.005    0.000 function_base.py:6(linspace)
#      3360    0.005    0.000    0.024    0.000 lil.py:289(__setitem__)
#      3600    0.005    0.000    0.019    0.000 numeric.py:65(zeros_like)
#      4727    0.005    0.000    0.005    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      7200    0.004    0.000    0.004    0.000 mesher.py:689(<genexpr>)
#       225    0.004    0.000    0.009    0.000 eqlayer.py:156(_rightside)
#      1129    0.004    0.000    0.005    0.000 sputils.py:116(_isinstance)
#      3600    0.003    0.000    0.003    0.000 mesher.py:49(__init__)
#       675    0.003    0.000    0.178    0.000 fromnumeric.py:445(transpose)
#       681    0.003    0.000    0.004    0.000 sputils.py:81(isintlike)
#      4023    0.003    0.000    0.007    0.000 numeric.py:237(asanyarray)
#       225    0.003    0.000    0.062    0.000 csc.py:116(__getitem__)
#         1    0.003    0.003    0.030    0.030 eqlayer.py:165(_pel_rmatrix)
#       225    0.003    0.000    0.010    0.000 mesher.py:663(__init__)
#         1    0.002    0.002    2.464    2.464 eqlayer.py:266(pel)
#       452    0.002    0.000    0.002    0.000 {numpy.core.multiarray.zeros}
#       226    0.002    0.000    0.006    0.000 sputils.py:18(upcast)
#       225    0.002    0.000    0.020    0.000 csc.py:84(transpose)
#       675    0.002    0.000    0.175    0.000 fromnumeric.py:32(_wrapit)
#       679    0.002    0.000    0.002    0.000 base.py:59(set_shape)
#         1    0.001    0.001    0.013    0.013 mesher.py:721(split)
#      1898    0.001    0.000    0.787    0.000 interface.py:232(matvec)
#       225    0.001    0.000    0.010    0.000 compressed.py:263(_mul_multivector)
#       225    0.001    0.000    0.018    0.000 csr.py:320(_get_submatrix)
#       225    0.001    0.000    0.001    0.000 {_csr.get_csr_submatrix}
#       680    0.001    0.000    0.001    0.000 sputils.py:96(isshape)
#       225    0.001    0.000    0.015    0.000 base.py:229(__mul__)
#         1    0.001    0.001    0.010    0.010 eqlayer.py:243(_coefs2prop)
#       225    0.001    0.000    0.015    0.000 csr.py:84(transpose)
#      2258    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      6073    0.001    0.000    0.001    0.000 base.py:81(get_shape)
#       679    0.001    0.000    0.001    0.000 base.py:51(__init__)
#       225    0.001    0.000    0.021    0.000 csr.py:163(__getitem__)
#      3600    0.001    0.000    0.001    0.000 {method 'conj' of 'numpy.ndarray' objects}
#      2714    0.001    0.000    0.001    0.000 compressed.py:85(getnnz)
#     12277    0.001    0.000    0.001    0.000 {len}
#       904    0.001    0.000    0.005    0.000 base.py:548(isspmatrix)
#       225    0.001    0.000    0.001    0.000 {_csc.csc_matvecs}
#         1    0.001    0.001    0.002    0.002 lil.py:423(tocsr)
#       678    0.001    0.000    0.002    0.000 sputils.py:50(to_native)
#       681    0.001    0.000    0.001    0.000 sputils.py:111(issequence)
#      3360    0.001    0.000    0.001    0.000 {_bisect.bisect_left}
#       678    0.001    0.000    0.002    0.000 data.py:17(__init__)
#       450    0.001    0.000    0.001    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#      6946    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      2260    0.001    0.000    0.001    0.000 {numpy.core.multiarray.can_cast}
#       225    0.001    0.000    0.002    0.000 function_base.py:3208(meshgrid)
#       234    0.001    0.000    0.001    0.000 {numpy.core.multiarray.empty}
#       452    0.001    0.000    0.001    0.000 {numpy.core.multiarray.arange}
#       450    0.001    0.000    0.036    0.000 base.py:370(__getattr__)
#         1    0.001    0.001    0.001    0.001 lil.py:59(__init__)
#       900    0.000    0.000    0.000    0.000 {zip}
#       678    0.000    0.000    0.000    0.000 sputils.py:54(getdtype)
#      2040    0.000    0.000    0.000    0.000 fromnumeric.py:2116(rank)
#       903    0.000    0.000    0.000    0.000 {getattr}
#         1    0.000    0.000    2.465    2.465 <string>:1(<module>)
#       675    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       678    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.dtype' objects}
#       450    0.000    0.000    0.000    0.000 csr.py:325(process_slice)
#      1353    0.000    0.000    0.000    0.000 csr.py:157(_swap)
#       225    0.000    0.000    0.002    0.000 sputils.py:77(isscalarlike)
#      3360    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       225    0.000    0.000    0.001    0.000 csc.py:216(csc_matvecs)
#       225    0.000    0.000    0.002    0.000 csr.py:586(get_csr_submatrix)
#      1898    0.000    0.000    0.000    0.000 utils.py:25(id)
#       225    0.000    0.000    0.000    0.000 fromnumeric.py:107(reshape)
#       450    0.000    0.000    0.000    0.000 csr.py:349(check_bounds)
#       681    0.000    0.000    0.000    0.000 csc.py:149(_swap)
#       225    0.000    0.000    0.001    0.000 sputils.py:124(isdense)
#       225    0.000    0.000    0.000    0.000 mesher.py:694(__iter__)
#         2    0.000    0.000    0.000    0.000 {method 'trace' of 'numpy.ndarray' objects}
#       226    0.000    0.000    0.000    0.000 data.py:20(_get_dtype)
#         3    0.000    0.000    0.000    0.000 {range}
#         1    0.000    0.000    0.000    0.000 {_csr.csr_tocsc}
#         1    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 csr.py:112(tocsc)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:986(trace)
#         1    0.000    0.000    0.000    0.000 utils.py:28(make_system)
#         1    0.000    0.000    0.000    0.000 interface.py:203(aslinearoperator)
#         2    0.000    0.000    0.000    0.000 interface.py:59(__init__)
#         3    0.000    0.000    0.000    0.000 eqlayer.py:87(_ncoefficients)
#         1    0.000    0.000    0.000    0.000 {numpy.core.multiarray.concatenate}
#         1    0.000    0.000    0.002    0.002 base.py:178(asformat)
#         1    0.000    0.000    0.000    0.000 shape_base.py:58(atleast_2d)
#         1    0.000    0.000    0.002    0.002 lil.py:445(tocsc)
#         3    0.000    0.000    0.000    0.000 {hasattr}
#         1    0.000    0.000    0.000    0.000 csr.py:177(csr_tocsc)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1643(cumsum)
#         1    0.000    0.000    0.000    0.000 compressed.py:597(__set_sorted)
#         1    0.000    0.000    0.000    0.000 compressed.py:90(_set_self)
#         1    0.000    0.000    0.000    0.000 utils.py:77(postprocess)
#         1    0.000    0.000    0.000    0.000 utils.py:18(coerce)
#         4    0.000    0.000    0.000    0.000 {sum}
#         2    0.000    0.000    0.000    0.000 eqlayer.py:222(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
lp = LineProfiler(gravmag.eqlayer.pel)
lp.runcall(gravmag.eqlayer.pel, data, grid, (15, 15), 1, 10.**-15, 10.**-1)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# File: /home/leo/src/fatiando/fatiando/gravmag/eqlayer.py
# Function: pel at line 266
# Total time: 2.66512 s
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    266                                           def pel(data, grid, windows, degree=1, damping=0., smoothness=0.,
#    267                                                   matrices=None):
#    268                                               """
#    269                                               The Polynomial Equivalent Layers
#    270                                               """
#    271         1            1      1.0      0.0      ny, nx = windows
#    272         1        17477  17477.0      0.7      grids = grid.split(nx, ny)
#    273         1            3      3.0      0.0      if grid.shape[1]%nx != 0 or grid.shape[0]%ny != 0:
#    274                                                   raise ValueError(
#    275                                                       'PEL requires windows to be divisable by the grid shape')
#    276         1            2      2.0      0.0      ngrids = len(grids)
#    277         1            4      4.0      0.0      pergrid = _ncoefficients(degree)
#    278         1            1      1.0      0.0      ncoefs = ngrids*pergrid
#    279         1            1      1.0      0.0      modelmatrix, smoothmatrix, rightside = _pel_matrices(data, windows, grid,
#    280         1      1703612 1703612.0     63.9          grids, degree)
#    281         1           88     88.0      0.0      fg = numpy.trace(modelmatrix)
#    282         1           35     35.0      0.0      fr = numpy.trace(smoothmatrix)
#    283         1         2262   2262.0      0.1      leftside = modelmatrix + (float(smoothness*fg)/fr)*smoothmatrix
#    284         1          485    485.0      0.0      leftside[range(ncoefs),range(ncoefs)] += float(damping*fg)/ncoefs
#    285         1       929272 929272.0     34.9      coefs, cgindex = linalg.cg(leftside, rightside)
#    286         1        11872  11872.0      0.4      estimate = _coefs2prop(coefs, grid, grids, windows, degree)
#    287         1            1      1.0      0.0      return estimate, [modelmatrix, smoothmatrix, rightside]

# %%
lp = LineProfiler(gravmag.eqlayer._pel_matrices)
lp.runcall(gravmag.eqlayer.pel, data, grid, (15, 15), 1, 10.**-15, 10.**-1)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# File: /home/leo/src/fatiando/fatiando/gravmag/eqlayer.py
# Function: _pel_matrices at line 192
# Total time: 1.66803 s
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    192                                           def _pel_matrices(data, windows, grid, grids, degree):
#    193                                               """
#    194                                               Compute the matrices needed by the PEL.
#    195
#    196                                               1. The Hessian of the model (B^TG^TGB)
#    197                                               2. The Hessian of smoothness (B^TR^TRB)
#    198                                               3. The right-side vector (B^TG^Td)
#    199
#    200                                               >>> from fatiando.mesher import PointGrid
#    201                                               >>> x, y, z, g = numpy.zeros((4, 500))
#    202                                               >>> data = [Gz(x, y, z, g)]
#    203                                               >>> grid = PointGrid((0, 10, 0, 10), 10, (10, 10))
#    204                                               >>> grid.size
#    205                                               100
#    206                                               >>> grids = grid.split(2, 2)
#    207                                               >>> print [g.size for g in grids]
#    208                                               [25, 25, 25, 25]
#    209                                               >>> model, smooth, right = _pel_matrices(data, (2, 2), grid, grids, 2)
#    210                                               >>> coefs = _ncoefficients(2)*len(grids)
#    211                                               >>> coefs
#    212                                               24
#    213                                               >>> model.shape
#    214                                               (24, 24)
#    215                                               >>> right.shape
#    216                                               (24,)
#    217
#    218                                               """
#    219         1            2      2.0      0.0      ngrids = len(grids)
#    220         1            4      4.0      0.0      pergrid = _ncoefficients(degree)
#    221         1            1      1.0      0.0      ncoefs = ngrids*pergrid
#    222         1            6      6.0      0.0      ndata = sum(d.size for d in data)
#    223                                               # make the finite differences matrix for the window borders
#    224         1        58474  58474.0      3.5      rmatrix, nderivs = _pel_rmatrix(windows, grid, grids)
#    225         1           65     65.0      0.0      rightside = numpy.empty(ncoefs, dtype=float)
#    226         1            4      4.0      0.0      gb = numpy.empty((ndata, ncoefs), dtype=float)
#    227         1            3      3.0      0.0      rb = numpy.empty((nderivs, ncoefs), dtype=float)
#    228         1            1      1.0      0.0      st = 0
#    229       226          331      1.5      0.0      for i, grid in enumerate(grids):
#    230       225        12825     57.0      0.8          bk = _bkmatrix(grid, degree)
#    231       225      1204141   5351.7     72.2          gkbk = numpy.dot(_gkmatrix(data, ndata, grid), bk)
#    232       225         6317     28.1      0.4          gb[:,i*pergrid:(i + 1)*pergrid] = gkbk
#    233                                                   # Make a part of the right-side vector
#    234       225         8654     38.5      0.5          rightside[i*pergrid:(i + 1)*pergrid] = _rightside(gkbk, data, pergrid)
#    235                                                   # Make the RB matrix
#    236       225          431      1.9      0.0          en = st + grid.size
#    237       225       108327    481.5      6.5          rb[:,i*pergrid:(i + 1)*pergrid] = rmatrix[:,st:en]*bk
#    238       225          432      1.9      0.0          st = en
#    239         1        81188  81188.0      4.9      modelmatrix = numpy.dot(gb.T, gb)
#    240         1       186820 186820.0     11.2      smoothmatrix = numpy.dot(rb.T, rb)
#    241         1            5      5.0      0.0      return modelmatrix, smoothmatrix, rightside
